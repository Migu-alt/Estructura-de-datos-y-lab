# %% [markdown]
# <a href="https://colab.research.google.com/github/Migu-alt/Estructura-de-datos-y-lab/blob/main/estructura.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import hashlib #con apoyo de gpt

text0= "hola"
text1= "Hola"
text2= "chao"
text3= "Chao"
text4= "XD"

def hash(text):
    hash_object = hashlib.sha256(text.encode())
    return hash_object.hexdigest()

def conc(text0, text1):
    return text0 + text1

def arbol(text0, text1, text2, text3):
    aux= hash(text0) + hash(text1)
    print(hash(aux))
    aux0= hash(text2) + hash(text3)
    print(hash(aux0))
    aux3= hash(text4)+ hash(text4)
    print(hash(aux3))
    aux= hash(aux) + hash(aux0)
    print(hash(aux))
    aux1= hash(aux) + hash(aux0)
    aux1= hash(aux1)
    return aux1

print(arbol(text0, text1, text2, text3))
# Out:
# 9ee22ff6973b22547db8df94fa1238bb82dd9c6f2736b61d453b3f890a42e71c
# 76ba913ce053dfc2018f2bd62d2bd5ade3de29a11d21efea95bc317f2252fe28
# 3cca7f6e73e7c6af84ea977130970d814e47f9590b6cdb8025798dcb52d0b643
# 1dcc6cb96f24d989ce597dbe1982dc2ea7b5608f86fe019fed481eed5d228168

# %%
import hashlib

class MerkleTree:    #hecho por gpt

    def __init__(self, transacciones):
        self.transacciones = transacciones
        self.root = self.construir_arbol()

    def hash(self, data):
        return hashlib.sha256(data.encode()).hexdigest()

    def construir_arbol(self):
        nivel = [self.hash(tx) for tx in self.transacciones]

        while len(nivel) > 1:

            if len(nivel) % 2 != 0:
                nivel.append(nivel[-1])

            nuevo_nivel = []

            for i in range(0, len(nivel), 2):
                combinado = nivel[i] + nivel[i+1]
                print("hijo1:",nivel[i],"hijo2:",nivel[i+1])
                nuevo_nivel.append(self.hash(combinado))

            print(nuevo_nivel)
            nivel = nuevo_nivel

        return nivel[0]


# Uso
transacciones = ["hola", "Hola", "chao", "Chao", "XD"]
merkle = MerkleTree(transacciones)

print("Merkle Root:", merkle.root)
# Out:
# hijo1: b221d9dbb083a7f33428d7c2a3c3198ae925614d70210e28716ccaa7cd4ddb79 hijo2: e633f4fc79badea1dc5db970cf397c8248bac47cc3acf9915ba60b5d76b0e88f
# hijo1: 266dd25dac03fce9c8fa8f7db4b64aebdfe91bbbae21b6c32ee6c9f899fe9a25 hijo2: 5d2b9ac6c65e4b9982a652dd0d8ebbcc3903b752580b319fe6392c1c94c9f121
# hijo1: 7a77dec6ccea995eddff86fad0769b88ab10898b2893887ceb47e7d8f1db8d38 hijo2: 7a77dec6ccea995eddff86fad0769b88ab10898b2893887ceb47e7d8f1db8d38
# ['9ee22ff6973b22547db8df94fa1238bb82dd9c6f2736b61d453b3f890a42e71c', '76ba913ce053dfc2018f2bd62d2bd5ade3de29a11d21efea95bc317f2252fe28', '3cca7f6e73e7c6af84ea977130970d814e47f9590b6cdb8025798dcb52d0b643']
# hijo1: 9ee22ff6973b22547db8df94fa1238bb82dd9c6f2736b61d453b3f890a42e71c hijo2: 76ba913ce053dfc2018f2bd62d2bd5ade3de29a11d21efea95bc317f2252fe28
# hijo1: 3cca7f6e73e7c6af84ea977130970d814e47f9590b6cdb8025798dcb52d0b643 hijo2: 3cca7f6e73e7c6af84ea977130970d814e47f9590b6cdb8025798dcb52d0b643
# ['1dcc6cb96f24d989ce597dbe1982dc2ea7b5608f86fe019fed481eed5d228168', '7d3a4b1ec8102ee197a88e6e8c6410be075ea4d2d7bfd8e42e6e7fb5abe5379a']
# hijo1: 1dcc6cb96f24d989ce597dbe1982dc2ea7b5608f86fe019fed481eed5d228168 hijo2: 7d3a4b1ec8102ee197a88e6e8c6410be075ea4d2d7bfd8e42e6e7fb5abe5379a
# ['e29ba56710bf2a99ac006c2c067d87d6efa1fcd73f2a9c391637d3aec0014009']
# Merkle Root: e29ba56710bf2a99ac006c2c067d87d6efa1fcd73f2a9c391637d3aec0014009
